# %% [markdown]
# # Problem 2: Getting familiar with TensorFlow
#
# *TensorFlow* is one of the most popular deep learning framework developed by Google. If you are new to TensorFlow, please read and play with the sample in [Getting started with TensorFlow](https://www.tensorflow.org/get_started/get_started) to get started.
#
# * <b>Learning Objective:</b> In Problem 1, you implemented a fully connected network from scratch on your own. Very tedious to do it all by yourself, right? Well, we actually feel the same thing, that's why we are using tools instead of doing everything from scratch, lonely and depressed. For this part of the assignment, we will familiarize you with a widely-used deep learning framework developed by Google, TensorFlow and walk you through convolutional neural networks and show how to train them.
# * <b>Provided Codes:</b> We provide the Template class for a simple CNN model as BaseModel, predefined skeletons for conv2d() and max_pool(), as well as the dataset preprocessing parts.
# * <b>TODOs:</b> You are asked to implement the BaseModel following the detailed instrunctions and design your own model in YourModel to achieve a reasonably good performance for classification task on CIFAR-10 dataset.

# %% [markdown]
# ## Install and import libraries
# Install tensorflow and matplotlib.
#
# ```
# pip install -U tensorflow matplotlib
# ```

# %%
# Import required libraries
# Add whatever you want
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

print "TensorFlow Version {}".format(tf.__version__)
# Out:
# TensorFlow Version 1.3.0

# %%
# Test matplotlib
x = np.linspace(-3, 3, 100)

plt.plot(x, np.maximum(0, x), label='relu')
plt.plot(x, 1/(1 + np.exp(-x)), label='sigmoid')
plt.plot(x, (1 - np.exp(-2 * x))/(1 + np.exp(-2 * x)), label='tanh')

plt.xlabel('x')
plt.ylabel('y')

plt.title("Activation functions")
plt.legend()
plt.grid(True)

plt.show()

# %%
# Test tensorflow
print('TensorFlow version: ' + tf.__version__)
a = tf.constant(2.0)
b = tf.constant(3.0)
c = a * b

sess = tf.Session()
result = sess.run([a, b, c])
print('%f * %f = %f' % (result[0], result[1], result[2]))
sess.close()
# Out:
# TensorFlow version: 1.3.0
# 2.000000 * 3.000000 = 6.000000

# %% [markdown]
# ## Load datasets
# Download [CIFAR-10](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz) and load the dataset. In this assignment, we will use all 50,000 images for training and 10,000 images for test.

# %%
# Configuration
num_training = 49000
num_validation = 50000 - num_training
num_test = 10000

def unpickle(file):
    import sys
    if sys.version_info.major == 2:
        import cPickle
        with open(file, 'rb') as fo:
            dict = cPickle.load(fo)
        return dict['data'], dict['labels']
    else:
        import pickle
        with open(file, 'rb') as fo:
            dict = pickle.load(fo, encoding='bytes')
        return dict[b'data'], dict[b'labels']

def load_train_data():
    pass

    #############################################################################
    # TODO: Load training data from cifar-10 dataset                            #
    # Load five files from 'data_batch_1' to 'data_batch_5'                     #
    # Reshape images and labels to the shape of [50000, 32, 32, 3]              # 
    # and [50000], respectively                                                 #
    #############################################################################
    import os
    all_batches = []
    all_labels = []
    data_path = 'data/cifar-10-batches-py/'
    for b in range(1,6):
        f_train_curr = os.path.join(data_path, 'data_batch_%d' % (b, ))
        raw_data, raw_labels = unpickle(f_train_curr)
        batch = raw_data.reshape(10000, 3, 32, 32).transpose(0,2,3,1).astype("float")
        labels = np.array(raw_labels)
        all_batches.append(batch)
        all_labels.append(labels)
    data_train = np.concatenate(all_batches)
    labels_train = np.concatenate(all_labels)
    del batch, labels
    data_val = data_train[range(num_training, num_training+num_validation)]
    labels_val = labels_train[range(num_training, num_training+num_validation)]
    data_train = data_train[range(num_training)]
    labels_train = labels_train[range(num_training)]
    return data_train, labels_train, data_val, labels_val
    #############################################################################
    #                             END OF YOUR CODE                              #
    #############################################################################

def load_test_data():
    pass

    #############################################################################
    # TODO: Load testing data from cifar-10 dataset                             #
    # Load 'test_batch' file                                                    #
    # Reshape images and labels to the shape of [10000, 32, 32, 3]              #
    # and [10000], respectively                                                 #
    #############################################################################
    import os
    data_path = 'data/cifar-10-batches-py/'
    f_test = os.path.join(data_path, 'test_batch')
    raw_data, raw_labels = unpickle(f_test)
    data_test = raw_data.reshape(10000, 3, 32, 32).transpose(0,2,3,1).astype("float")
    labels_test = np.array(raw_labels)
    return data_test, labels_test
    #############################################################################
    #                             END OF YOUR CODE                              #
    #############################################################################

# Load cifar-10 data
X_train, Y_train, X_val, Y_val = load_train_data()
X_test, Y_test = load_test_data()

# Check the shape of the dataset
assert X_train.shape == (num_training, 32, 32, 3)
assert Y_train.shape == (num_training, )
assert X_val.shape == (num_validation, 32, 32, 3)
assert Y_val.shape == (num_validation, )
assert X_test.shape == (num_test, 32, 32, 3)
assert Y_test.shape == (10000, )

# %% [markdown]
# ## Question 2-1
#
# Using the code provided, implement a neural network architecture with an optimization routine according to the specification provided below.
#
# **Model:**
# - Input image with the size 32x32x3
# - 7x7 convolutional layer with 32 filters, stride of 1, and padding 'SAME'
# - ReLU activation layer
# - 3x3 max pooling layer with a stride of 2
# - 5x5 convolutional layer with 64 filters, stride of 1, and padding 'SAME'
# - ReLU activation layer
# - 3x3 max pooling layer with a stride of 2
# - Flatten layer (8x8x64 -> 4096)
# - Fully-connected layer with 384 output units (4096 -> 384)
# - ReLU activation layer
# - Fully-connected layer with 10 output units (384 -> 10)
# - Output logits (10)
#
# **Optimizer:**
# - Adam optimizer
#
# **Learning rate:**
# - Set start learning rate as 5e-4 and apply exponential decay every 500 steps with a base of 0.96
# - Use 'tf.train.exponential_decay' and 'tf.train.AdamOptimizer'
#
# **Loss:**
# - Softmax cross entropy loss
# - Use 'tf.nn.softmax_cross_entropy_with_logits'
#
#
# Your model **should** achieve about 60% accuracy on validation set in 5 epochs using provided evaluation code.
#
# You can modify the template code as you want.

# %% [markdown]
# ## Define your layers

# %%
# Define max pooling and conv layers
def conv2d(input, kernel_size, stride, num_filter):
    stride_shape = [1, stride, stride, 1]
    filter_shape = [kernel_size, kernel_size, input.get_shape()[3], num_filter]

    W = tf.get_variable('w', filter_shape, tf.float32, tf.random_normal_initializer(0.0, 0.02))
    b = tf.get_variable('b', [1, 1, 1, num_filter], initializer=tf.constant_initializer(0.0))
    return tf.nn.conv2d(input, W, stride_shape, padding='SAME') + b

def max_pool(input, kernel_size, stride):
    ksize = [1, kernel_size, kernel_size, 1]
    strides = [1, stride, stride, 1]
    return tf.nn.max_pool(input, ksize=ksize, strides=strides, padding='SAME')

#############################################################################
# TODO: You can add any layers (fully-connected, normalization)             #
#############################################################################
def fully_connect(inputs, num_outputs):
    return tf.contrib.layers.fully_connected(
        inputs=inputs,
        num_outputs=num_outputs,
        activation_fn=None,
        weights_initializer=tf.contrib.layers.xavier_initializer(),
        biases_initializer=tf.zeros_initializer(),
    )

def avg_pool(input, kernel_size, stride):
    ksize = [1, kernel_size, kernel_size, 1]
    strides = [1, stride, stride, 1]
    return tf.nn.avg_pool(input, ksize=ksize, strides=strides, padding='SAME')
#############################################################################
#                             END OF YOUR CODE                              #
#############################################################################

# %% [markdown]
# ## Sample convolutional nueral network

# %%
class BaseModel(object):
    def __init__(self):
        self.num_epoch = 5
        self.batch_size = 128
        self.log_step = 50
        self._build_model()

    def _model(self):
        print('-' * 5 + '  Sample model  ' + '-' * 5)

        print('intput layer: ' + str(self.X.get_shape()))

        with tf.variable_scope('conv1'):
            self.conv1 = conv2d(self.X, 7, 1, 32)
            self.relu1 = tf.nn.relu(self.conv1)
            self.pool1 = max_pool(self.relu1, 3, 2)            
            print('conv1 layer: ' + str(self.pool1.get_shape()))

        with tf.variable_scope('conv2'):
            #############################################################################
            # TODO: Complete the following functions                                    #
            #############################################################################
            self.conv2 = conv2d(self.pool1, 5, 1, 64)
            self.relu2 = tf.nn.relu(self.conv2)
            self.pool2 = max_pool(self.relu2, 3, 2)            
            #############################################################################
            #                             END OF YOUR CODE                              #
            #############################################################################
            print('conv2 layer: ' + str(self.pool2.get_shape()))


        #############################################################################
        # TODO: Flatten the output tensor from conv2 layer                          #
        #############################################################################
        self.flat = tf.contrib.layers.flatten(self.pool2, scope='flat')
        #############################################################################
        #                             END OF YOUR CODE                              #
        #############################################################################      
        print('flat layer: ' + str(self.flat.get_shape()))

        with tf.variable_scope('fc3'):
            #############################################################################
            # TODO: Complete the following functions                                    #
            #############################################################################
            self.fc3 = fully_connect(self.flat, 384)
            self.relu3 = tf.nn.relu(self.fc3)
            #############################################################################
            #                             END OF YOUR CODE                              #
            #############################################################################
            print('fc3 layer: ' + str(self.relu3.get_shape()))

        with tf.variable_scope('fc4'):
            #############################################################################
            # TODO: Complete the following functions                                    #
            #############################################################################
            self.fc4 = fully_connect(self.relu3, 10)            
            #############################################################################
            #                             END OF YOUR CODE                              #
            #############################################################################
            print('fc4 layer: ' + str(self.fc4.get_shape()))
        
        # Return the last layer
        return self.fc4

    def _input_ops(self):
        # Placeholders
        self.X = tf.placeholder(tf.float32, [None, 32, 32, 3])
        self.Y = tf.placeholder(tf.int64, [None])
        
        #############################################################################
        # TODO: You can add any placeholders                                        #
        #############################################################################
        self.is_train = None
        self.keep_prob = None
        self.global_step = tf.Variable(0, trainable=False)
        #############################################################################
        #                             END OF YOUR CODE                              #
        #############################################################################

    def _build_optimizer(self):
        # Adam optimizer 'self.train_op' that minimizes 'self.loss_op'
        #############################################################################
        # TODO: Complete the following functions                                    #
        #############################################################################
        self.learning_rate = tf.train.exponential_decay(
            learning_rate=5e-4,
            global_step=self.global_step,
            decay_steps=500,
            decay_rate=0.96
        )
        self.train_op = tf.train.AdamOptimizer(learning_rate=self.learning_rate).minimize(self.loss_op)        
        #############################################################################
        #                             END OF YOUR CODE                              #
        #############################################################################
        
    def _loss(self, labels, logits):
        # Softmax cross entropy loss 'self.loss_op'
        #############################################################################
        # TODO: Complete the following functions                                    #
        #############################################################################
        self.loss_op = tf.reduce_mean(
            tf.nn.softmax_cross_entropy_with_logits(labels=labels, logits=logits),
            axis=0
        )        
        #############################################################################
        #                             END OF YOUR CODE                              #
        #############################################################################

    def _build_model(self):
        # Define input variables
        self._input_ops()

        # Convert Y to one-hot vector
        labels = tf.one_hot(self.Y, 10)

        # Build a model and get logits
        logits = self._model()

        # Compute loss
        self._loss(labels, logits)
        
        # Build optimizer
        self._build_optimizer()

        # Compute accuracy
        predict = tf.argmax(logits, 1)
        correct = tf.equal(predict, self.Y)
        self.accuracy_op = tf.reduce_mean(tf.cast(correct, tf.float32))
        
    def train(self, sess, X_train, Y_train, X_val, Y_val):
        sess.run(tf.global_variables_initializer())

        step = 0
        losses = []
        accuracies = []
        print('-' * 5 + '  Start training  ' + '-' * 5)
        for epoch in range(self.num_epoch):
            print('train for epoch %d' % epoch)
            for i in range(num_training // self.batch_size):
                X_ = X_train[i * self.batch_size:(i + 1) * self.batch_size][:]
                Y_ = Y_train[i * self.batch_size:(i + 1) * self.batch_size]

                #############################################################################
                # TODO: You can change feed data as you want                                #
                #############################################################################
                feed_dict = {self.X: X_, self.Y: Y_, self.global_step: step}               
                #############################################################################
                #                             END OF YOUR CODE                              #
                #############################################################################
                fetches = [self.train_op, self.loss_op, self.accuracy_op]

                _, loss, accuracy = sess.run(fetches, feed_dict=feed_dict)
                losses.append(loss)
                accuracies.append(accuracy)

                if step % self.log_step == 0:
                    print('iteration (%d): loss = %.3f, accuracy = %.3f' %
                        (step, loss, accuracy))
                step += 1

            #############################################################################
            # TODO: Plot training curves                                                #
            #############################################################################
            # Graph 1. X: epoch, Y: training loss
            fig = plt.figure(figsize=(15, 12))
            fig.add_subplot(2, 1, 1)
            plt.title('Training loss_{}'.format(epoch))
            x = [i for i in range(num_training // self.batch_size)]
            plt.plot(x, losses[(step - num_training // self.batch_size):step], '-o')
            plt.xlabel('Epoch_{}'.format(epoch))
            # Graph 2. X: epoch, Y: training accuracy
            fig.add_subplot(2, 1, 2)
            plt.title('Training accuracy_{}'.format(epoch))
            plt.plot(x, accuracies[(step - num_training // self.batch_size):step], '-b')
            plt.xlabel('Epoch_{}'.format(epoch))
            plt.show()
            #############################################################################
            #                             END OF YOUR CODE                              #
            #############################################################################

            # Print validation results
            print('validation for epoch %d' % epoch)
            val_accuracy = self.evaluate(sess, X_val, Y_val)
            print('-  epoch %d: validation accuracy = %.3f' % (epoch, val_accuracy))

    def evaluate(self, sess, X_eval, Y_eval):
        eval_accuracy = 0.0
        eval_iter = 0
        for i in range(X_eval.shape[0] // self.batch_size):
            X_ = X_eval[i * self.batch_size:(i + 1) * self.batch_size][:]
            Y_ = Y_eval[i * self.batch_size:(i + 1) * self.batch_size]
                        
            #############################################################################
            # TODO: You can change feed data as you want                                #
            #############################################################################
            feed_dict = {self.X: X_, self.Y: Y_}
            #############################################################################
            #                             END OF YOUR CODE                              #
            #############################################################################
            accuracy = sess.run(self.accuracy_op, feed_dict=feed_dict)
            eval_accuracy += accuracy
            eval_iter += 1
        return eval_accuracy / eval_iter

# %%
# Clear old computation graphs
tf.reset_default_graph()

# Train our sample model
with tf.Session() as sess:
    with tf.device('/cpu:0'):
        model = BaseModel()
        model.train(sess, X_train, Y_train, X_val, Y_val)
        accuracy = model.evaluate(sess, X_test, Y_test)
        print('***** test accuracy: %.3f' % accuracy)
        saver = tf.train.Saver()
        model_path = saver.save(sess, "lib/tf_models/problem2/csci-599_sample.ckpt")
        print("Model saved in %s" % model_path)
# Out:
# -----  Sample model  -----
# intput layer: (?, 32, 32, 3)
# conv1 layer: (?, 16, 16, 32)
# conv2 layer: (?, 8, 8, 64)
# flat layer: (?, 4096)
# fc3 layer: (?, 384)
# fc4 layer: (?, 10)
# -----  Start training  -----
# train for epoch 0
# iteration (0): loss = 19.019, accuracy = 0.047
# iteration (50): loss = 1.898, accuracy = 0.328
# iteration (100): loss = 1.741, accuracy = 0.359
# iteration (150): loss = 1.701, accuracy = 0.367
# iteration (200): loss = 1.716, accuracy = 0.391
# iteration (250): loss = 1.735, accuracy = 0.383
# iteration (300): loss = 1.574, accuracy = 0.453
# iteration (350): loss = 1.534, accuracy = 0.445
# validation for epoch 0
# -  epoch 0: validation accuracy = 0.498
# train for epoch 1
# iteration (400): loss = 1.462, accuracy = 0.508
# iteration (450): loss = 1.422, accuracy = 0.422
# iteration (500): loss = 1.354, accuracy = 0.492
# iteration (550): loss = 1.207, accuracy = 0.562
# iteration (600): loss = 1.407, accuracy = 0.477
# iteration (650): loss = 1.543, accuracy = 0.516
# iteration (700): loss = 1.248, accuracy = 0.562
# iteration (750): loss = 1.095, accuracy = 0.602
# validation for epoch 1
# -  epoch 1: validation accuracy = 0.554
# train for epoch 2
# iteration (800): loss = 1.145, accuracy = 0.562
# iteration (850): loss = 1.295, accuracy = 0.547
# iteration (900): loss = 1.186, accuracy = 0.609
# iteration (950): loss = 1.058, accuracy = 0.648
# iteration (1000): loss = 1.173, accuracy = 0.586
# iteration (1050): loss = 1.069, accuracy = 0.656
# iteration (1100): loss = 0.915, accuracy = 0.656
# validation for epoch 2
# -  epoch 2: validation accuracy = 0.610
# train for epoch 3
# iteration (1150): loss = 1.043, accuracy = 0.641
# iteration (1200): loss = 0.964, accuracy = 0.680
# iteration (1250): loss = 1.130, accuracy = 0.625
# iteration (1300): loss = 1.193, accuracy = 0.602
# iteration (1350): loss = 0.931, accuracy = 0.680
# iteration (1400): loss = 1.094, accuracy = 0.648
# iteration (1450): loss = 0.966, accuracy = 0.625
# iteration (1500): loss = 0.854, accuracy = 0.703
# validation for epoch 3
# -  epoch 3: validation accuracy = 0.609
# train for epoch 4
# iteration (1550): loss = 0.802, accuracy = 0.727
# iteration (1600): loss = 0.898, accuracy = 0.664
# iteration (1650): loss = 1.003, accuracy = 0.625
# iteration (1700): loss = 0.939, accuracy = 0.664
# iteration (1750): loss = 0.957, accuracy = 0.641
# iteration (1800): loss = 0.818, accuracy = 0.703
# iteration (1850): loss = 0.948, accuracy = 0.648
# iteration (1900): loss = 0.875, accuracy = 0.711
# validation for epoch 4
# -  epoch 4: validation accuracy = 0.638
# ***** test accuracy: 0.606
# Model saved in lib/tf_models/problem2/csci-599_sample.ckpt

# %% [markdown]
# ## Question 2-2
#
# Implement your own model.
#
# You can modify the template code as you want and you can use GPU for fast training.
#
# These are the techniques that you can try:
# - Data preprocessing
# - Data augmentation
# - Dropout
# - Batch normalization
# - More convolutional layers
# - More training epochs
# - Learning rate decay
# - Any other models and techniqes
#
# Your model should achieve >= 70% accuracy on the test set of CIFAR-10.
#
# If the accuracy of the model reaches to 80% on the test set, you will get 5 extra points.

# %%
class YourModel(BaseModel):
    def __init__(self):
        super(YourModel, self).__init__()
        self.num_epoch = 10
        self.batch_size = 64

    def _model(self):
        print('-' * 5 + '  Your model  ' + '-' * 5)

        #############################################################################
        # TODO: Implement you own model here                                        #
        #############################################################################
        with tf.variable_scope('conv1'):
            self.conv1 = self.conv2d(self.X, 5, 1, 32, 0.01)
            self.pool1 = self.max_pool(self.conv1, 3, 2)
            self.relu1 = tf.nn.relu(self.pool1)
            print('conv1 layer: ' + str(self.pool1.get_shape()))

        with tf.variable_scope('conv2'):
            self.conv2 = self.conv2d(self.relu1, 3, 1, 64, 0.01)
            self.relu2 = tf.nn.relu(self.conv2)
            self.pool2 = self.avg_pool(self.relu2, 3, 2)
            print('conv2 layer: ' + str(self.pool2.get_shape()))

        with tf.variable_scope('conv3'):
            self.conv3 = self.conv2d(self.pool2, 1, 1, 128, 0.01)
            self.relu3 = tf.nn.relu(self.conv3)
            self.pool3 = self.avg_pool(self.relu3, 3, 2)
            print('conv3 layer: ' + str(self.pool3.get_shape()))

        self.flat = tf.contrib.layers.flatten(self.pool3, scope='flat')
        print('flat layer: ' + str(self.flat.get_shape()))

        with tf.variable_scope('fc4'):
            self.fc4 = self.fully_connect(self.flat, 10, 0.1)
            print('fc4 layer: ' + str(self.fc4.get_shape()))

        return self.fc4
        #############################################################################
        #                             END OF YOUR CODE                              #
        #############################################################################

    #############################################################################
    # TODO: You can redefine BaseModel's methods                                #
    #############################################################################
    def conv2d(self, input, kernel_size, stride, num_filter, stddev):
        stride_shape = [1, stride, stride, 1]
        filter_shape = [kernel_size, kernel_size, input.get_shape()[3], num_filter]

        W = tf.get_variable('w', filter_shape, tf.float32, tf.random_normal_initializer(0.0, stddev))
        b = tf.get_variable('b', [1, 1, 1, num_filter], initializer=tf.constant_initializer(0.0))
        return tf.nn.conv2d(input, W, stride_shape, padding='SAME') + b

    def max_pool(self, input, kernel_size, stride):
        ksize = [1, kernel_size, kernel_size, 1]
        strides = [1, stride, stride, 1]
        return tf.nn.max_pool(input, ksize=ksize, strides=strides, padding='SAME')

    def fully_connect(self, inputs, num_outputs, stddev):
        return tf.contrib.layers.fully_connected(
            inputs=inputs,
            num_outputs=num_outputs,
            activation_fn=None,
            weights_initializer=tf.random_normal_initializer(0.0, stddev),
            biases_initializer=tf.zeros_initializer(),
        )

    def avg_pool(self, input, kernel_size, stride):
        ksize = [1, kernel_size, kernel_size, 1]
        strides = [1, stride, stride, 1]
        return tf.nn.avg_pool(input, ksize=ksize, strides=strides, padding='SAME')
    
    def _input_ops(self):
        # Placeholders
        self.X = tf.placeholder(tf.float32, [None, 32, 32, 3])
        self.Y = tf.placeholder(tf.int64, [None])

        self.is_train = True
        self.weight_decay = 0.004
        self.keep_prob = 0.5
        self.num_classes = 10
        self.global_step = tf.Variable(0, trainable=False)

    def _build_optimizer(self):
        self.learning_rate = tf.train.exponential_decay(
            learning_rate=5e-4,
            global_step=self.global_step,
            decay_steps=500,
            decay_rate=0.96
        )
        self.train_op = tf.train.AdamOptimizer(learning_rate=self.learning_rate).minimize(self.loss_op)

    def _loss(self, labels, logits):
        self.loss_op = tf.reduce_mean(
            tf.nn.softmax_cross_entropy_with_logits(labels=labels, logits=logits),
            axis=0
        )

    def _build_model(self):
        # Define input variables
        self._input_ops()

        # Convert Y to one-hot vector
        labels = tf.one_hot(self.Y, 10)

        # Build a model and get logits
        logits = self._model()

        # Compute loss
        self._loss(labels, logits)

        # Build optimizer
        self._build_optimizer()

        # Compute accuracy
        predict = tf.argmax(logits, 1)
        correct = tf.equal(predict, self.Y)
        self.accuracy_op = tf.reduce_mean(tf.cast(correct, tf.float32))

    def train(self, sess, X_train, Y_train, X_val, Y_val):
        sess.run(tf.global_variables_initializer())

        step = 0
        losses = []
        accuracies = []
        print('-' * 5 + '  Start training  ' + '-' * 5)
        for epoch in range(self.num_epoch):
            print('train for epoch %d' % epoch)
            for i in range(num_training // self.batch_size):
                X_ = X_train[i * self.batch_size:(i + 1) * self.batch_size][:]
                Y_ = Y_train[i * self.batch_size:(i + 1) * self.batch_size]

                feed_dict = {self.X: X_, self.Y: Y_, self.global_step: step}
                fetches = [self.train_op, self.loss_op, self.accuracy_op]

                _, loss, accuracy = sess.run(fetches, feed_dict=feed_dict)
                losses.append(loss)
                accuracies.append(accuracy)

                if step % self.log_step == 0:
                    print('iteration (%d): loss = %.3f, accuracy = %.3f' %
                          (step, loss, accuracy))

                step += 1

            # Print validation results
            print('validation for epoch %d' % epoch)
            val_accuracy = self.evaluate(sess, X_val, Y_val)
            print('-  epoch %d: validation accuracy = %.3f' % (epoch, val_accuracy))

    def evaluate(self, sess, X_eval, Y_eval):
        eval_accuracy = 0.0
        eval_iter = 0
        for i in range(X_eval.shape[0] // self.batch_size):
            X_ = X_eval[i * self.batch_size:(i + 1) * self.batch_size][:]
            Y_ = Y_eval[i * self.batch_size:(i + 1) * self.batch_size]

            feed_dict = {self.X: X_, self.Y: Y_}

            accuracy = sess.run(self.accuracy_op, feed_dict=feed_dict)
            eval_accuracy += accuracy
            eval_iter += 1
        return eval_accuracy / eval_iter
    #############################################################################
    #                             END OF YOUR CODE                              #
    #############################################################################

# %%
# Clear old computation graphs
tf.reset_default_graph()

sess = tf.Session()

#############################################################################
# TODO: Preprocessing                                                       #
#############################################################################
X_train_ = X_train.copy()
X_val_ = X_val.copy()
X_test_ = X_test.copy()
#############################################################################
#                             END OF YOUR CODE                              #
#############################################################################

model = YourModel()
model.train(sess, X_train_, Y_train, X_val_, Y_val)
accuracy = model.evaluate(sess, X_test_, Y_test)
print('***** test accuracy: %.3f' % accuracy)

# Save your model
saver = tf.train.Saver()
model_path = saver.save(sess, "lib/tf_models/problem2/csci-599_mine.ckpt")
print("Model saved in %s" % model_path)

sess.close()
# Out:
# -----  Your model  -----
# conv1 layer: (?, 16, 16, 32)
# conv2 layer: (?, 8, 8, 64)
# conv3 layer: (?, 4, 4, 128)
# flat layer: (?, 2048)
# fc4 layer: (?, 10)
# -----  Start training  -----
# train for epoch 0
# iteration (0): loss = 2.286, accuracy = 0.172
# iteration (50): loss = 1.971, accuracy = 0.328
# iteration (100): loss = 1.757, accuracy = 0.297
# iteration (150): loss = 1.614, accuracy = 0.469
# iteration (200): loss = 1.506, accuracy = 0.438
# iteration (250): loss = 1.470, accuracy = 0.453
# iteration (300): loss = 1.621, accuracy = 0.344
# iteration (350): loss = 1.536, accuracy = 0.422
# iteration (400): loss = 1.551, accuracy = 0.438
# iteration (450): loss = 1.242, accuracy = 0.625
# iteration (500): loss = 1.509, accuracy = 0.500
# iteration (550): loss = 1.360, accuracy = 0.469
# iteration (600): loss = 1.574, accuracy = 0.469
# iteration (650): loss = 1.404, accuracy = 0.484
# iteration (700): loss = 1.523, accuracy = 0.453
# iteration (750): loss = 1.611, accuracy = 0.453
# validation for epoch 0
# -  epoch 0: validation accuracy = 0.517
# train for epoch 1
# iteration (800): loss = 1.360, accuracy = 0.578
# iteration (850): loss = 1.430, accuracy = 0.484
# iteration (900): loss = 1.231, accuracy = 0.578
# iteration (950): loss = 1.427, accuracy = 0.516
# iteration (1000): loss = 1.391, accuracy = 0.562
# iteration (1050): loss = 1.333, accuracy = 0.531
# iteration (1100): loss = 1.435, accuracy = 0.500
# iteration (1150): loss = 1.159, accuracy = 0.625
# iteration (1200): loss = 1.478, accuracy = 0.500
# iteration (1250): loss = 1.151, accuracy = 0.547
# iteration (1300): loss = 0.987, accuracy = 0.641
# iteration (1350): loss = 1.336, accuracy = 0.500
# iteration (1400): loss = 1.005, accuracy = 0.625
# iteration (1450): loss = 1.306, accuracy = 0.562
# iteration (1500): loss = 1.199, accuracy = 0.594
# validation for epoch 1
# -  epoch 1: validation accuracy = 0.584
# train for epoch 2
# iteration (1550): loss = 1.401, accuracy = 0.438
# iteration (1600): loss = 1.352, accuracy = 0.531
# iteration (1650): loss = 1.133, accuracy = 0.625
# iteration (1700): loss = 1.458, accuracy = 0.438
# iteration (1750): loss = 1.219, accuracy = 0.578
# iteration (1800): loss = 1.036, accuracy = 0.625
# iteration (1850): loss = 1.246, accuracy = 0.625
# iteration (1900): loss = 0.810, accuracy = 0.766
# iteration (1950): loss = 1.252, accuracy = 0.547
# iteration (2000): loss = 1.188, accuracy = 0.609
# iteration (2050): loss = 1.195, accuracy = 0.547
# iteration (2100): loss = 1.093, accuracy = 0.641
# iteration (2150): loss = 1.249, accuracy = 0.594
# iteration (2200): loss = 1.319, accuracy = 0.625
# iteration (2250): loss = 0.762, accuracy = 0.734
# validation for epoch 2
# -  epoch 2: validation accuracy = 0.630
# train for epoch 3
# iteration (2300): loss = 1.079, accuracy = 0.625
# iteration (2350): loss = 0.911, accuracy = 0.641
# iteration (2400): loss = 1.009, accuracy = 0.641
# iteration (2450): loss = 1.027, accuracy = 0.672
# iteration (2500): loss = 1.007, accuracy = 0.688
# iteration (2550): loss = 0.851, accuracy = 0.734
# iteration (2600): loss = 1.307, accuracy = 0.594
# iteration (2650): loss = 0.964, accuracy = 0.703
# iteration (2700): loss = 0.988, accuracy = 0.625
# iteration (2750): loss = 1.224, accuracy = 0.578
# iteration (2800): loss = 0.996, accuracy = 0.719
# iteration (2850): loss = 0.862, accuracy = 0.672
# iteration (2900): loss = 0.823, accuracy = 0.688
# iteration (2950): loss = 1.317, accuracy = 0.578
# iteration (3000): loss = 1.055, accuracy = 0.688
# iteration (3050): loss = 0.906, accuracy = 0.750
# validation for epoch 3
# -  epoch 3: validation accuracy = 0.657
# train for epoch 4
# iteration (3100): loss = 0.771, accuracy = 0.734
# iteration (3150): loss = 0.931, accuracy = 0.625
# iteration (3200): loss = 1.375, accuracy = 0.531
# iteration (3250): loss = 0.849, accuracy = 0.688
# iteration (3300): loss = 0.932, accuracy = 0.609
# iteration (3350): loss = 0.969, accuracy = 0.672
# iteration (3400): loss = 0.993, accuracy = 0.672
# iteration (3450): loss = 0.812, accuracy = 0.672
# iteration (3500): loss = 0.976, accuracy = 0.594
# iteration (3550): loss = 1.237, accuracy = 0.594
# iteration (3600): loss = 0.866, accuracy = 0.719
# iteration (3650): loss = 1.095, accuracy = 0.641
# iteration (3700): loss = 0.874, accuracy = 0.656
# iteration (3750): loss = 1.182, accuracy = 0.625
# iteration (3800): loss = 0.992, accuracy = 0.641
# validation for epoch 4
# -  epoch 4: validation accuracy = 0.664
# train for epoch 5
# iteration (3850): loss = 0.870, accuracy = 0.703
# iteration (3900): loss = 1.143, accuracy = 0.641
# iteration (3950): loss = 0.821, accuracy = 0.688
# iteration (4000): loss = 0.830, accuracy = 0.656
# iteration (4050): loss = 0.982, accuracy = 0.688
# iteration (4100): loss = 0.816, accuracy = 0.688
# iteration (4150): loss = 0.954, accuracy = 0.641
# iteration (4200): loss = 0.684, accuracy = 0.688
# iteration (4250): loss = 0.996, accuracy = 0.625
# iteration (4300): loss = 0.906, accuracy = 0.688
# iteration (4350): loss = 1.190, accuracy = 0.609
# iteration (4400): loss = 1.022, accuracy = 0.703
# iteration (4450): loss = 0.805, accuracy = 0.703
# iteration (4500): loss = 1.020, accuracy = 0.578
# iteration (4550): loss = 0.755, accuracy = 0.734
# validation for epoch 5
# -  epoch 5: validation accuracy = 0.669
# train for epoch 6
# iteration (4600): loss = 0.983, accuracy = 0.609
# iteration (4650): loss = 1.020, accuracy = 0.609
# iteration (4700): loss = 1.157, accuracy = 0.625
# iteration (4750): loss = 0.863, accuracy = 0.750
# iteration (4800): loss = 0.682, accuracy = 0.812
# iteration (4850): loss = 0.977, accuracy = 0.625
# iteration (4900): loss = 0.905, accuracy = 0.719
# iteration (4950): loss = 0.824, accuracy = 0.781
# iteration (5000): loss = 1.056, accuracy = 0.625
# iteration (5050): loss = 0.861, accuracy = 0.656
# iteration (5100): loss = 0.706, accuracy = 0.797
# iteration (5150): loss = 0.776, accuracy = 0.734
# iteration (5200): loss = 1.059, accuracy = 0.594
# iteration (5250): loss = 0.726, accuracy = 0.766
# iteration (5300): loss = 0.797, accuracy = 0.625
# iteration (5350): loss = 0.748, accuracy = 0.766
# validation for epoch 6
# -  epoch 6: validation accuracy = 0.685
# train for epoch 7
# iteration (5400): loss = 0.742, accuracy = 0.734
# iteration (5450): loss = 1.115, accuracy = 0.594
# iteration (5500): loss = 0.707, accuracy = 0.703
# iteration (5550): loss = 0.995, accuracy = 0.625
# iteration (5600): loss = 1.226, accuracy = 0.625
# iteration (5650): loss = 0.763, accuracy = 0.766
# iteration (5700): loss = 0.889, accuracy = 0.703
# iteration (5750): loss = 0.831, accuracy = 0.766
# iteration (5800): loss = 0.828, accuracy = 0.750
# iteration (5850): loss = 0.689, accuracy = 0.766
# iteration (5900): loss = 0.694, accuracy = 0.734
# iteration (5950): loss = 1.000, accuracy = 0.594
# iteration (6000): loss = 0.906, accuracy = 0.719
# iteration (6050): loss = 0.915, accuracy = 0.625
# iteration (6100): loss = 0.930, accuracy = 0.594
# validation for epoch 7
# -  epoch 7: validation accuracy = 0.693
# train for epoch 8
# iteration (6150): loss = 0.899, accuracy = 0.688
# iteration (6200): loss = 1.039, accuracy = 0.609
# iteration (6250): loss = 0.658, accuracy = 0.781
# iteration (6300): loss = 0.810, accuracy = 0.688
# iteration (6350): loss = 0.711, accuracy = 0.750
# iteration (6400): loss = 0.646, accuracy = 0.781
# iteration (6450): loss = 0.831, accuracy = 0.781
# iteration (6500): loss = 0.781, accuracy = 0.766
# iteration (6550): loss = 0.839, accuracy = 0.781
# iteration (6600): loss = 0.868, accuracy = 0.656
# iteration (6650): loss = 0.830, accuracy = 0.719
# iteration (6700): loss = 0.944, accuracy = 0.672
# iteration (6750): loss = 0.961, accuracy = 0.641
# iteration (6800): loss = 0.835, accuracy = 0.672
# iteration (6850): loss = 0.738, accuracy = 0.750
# validation for epoch 8
# -  epoch 8: validation accuracy = 0.707
# train for epoch 9
# iteration (6900): loss = 0.643, accuracy = 0.781
# iteration (6950): loss = 0.763, accuracy = 0.750
# iteration (7000): loss = 0.992, accuracy = 0.641
# iteration (7050): loss = 0.890, accuracy = 0.734
# iteration (7100): loss = 0.718, accuracy = 0.734
# iteration (7150): loss = 0.723, accuracy = 0.766
# iteration (7200): loss = 0.650, accuracy = 0.812
# iteration (7250): loss = 0.702, accuracy = 0.766
# iteration (7300): loss = 0.749, accuracy = 0.766
# iteration (7350): loss = 0.627, accuracy = 0.766
# iteration (7400): loss = 0.684, accuracy = 0.719
# iteration (7450): loss = 1.016, accuracy = 0.641
# iteration (7500): loss = 0.869, accuracy = 0.672
# iteration (7550): loss = 0.983, accuracy = 0.609
# iteration (7600): loss = 0.696, accuracy = 0.672
# validation for epoch 9
# -  epoch 9: validation accuracy = 0.714
# ***** test accuracy: 0.709
# Model saved in lib/tf_models/problem2/csci-599_mine.ckpt

# %%
tf.reset_default_graph()

# Load your model
model = YourModel()
sess = tf.Session()
saver = tf.train.Saver()
saver.restore(sess, "lib/tf_models/problem2/csci-599_mine.ckpt")
# Out:
# -----  Your model  -----
# conv1 layer: (?, 16, 16, 32)
# conv2 layer: (?, 8, 8, 64)
# conv3 layer: (?, 4, 4, 128)
# flat layer: (?, 2048)
# fc4 layer: (?, 10)
# INFO:tensorflow:Restoring parameters from lib/tf_models/problem2/csci-599_mine.ckpt
